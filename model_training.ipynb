# %% [markdown]
# # 1. Imports

# %%
import os, random
from dataclasses import dataclass

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from PIL import Image

# %%
@dataclass
class config:
    img_size: int = 84 
    batch_size: int = 64
    lr: float = 3e-4
    epochs = 10
    num_workers: int = 2
    device: str = "cuda" if torch.cuda.is_available() else "cpu"

config()
# Out:
# config(img_size=84, batch_size=64, lr=0.0003, num_workers=2, device='cpu')
